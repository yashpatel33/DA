# %%
import numpy as np
import pandas as pd
a=np.random.rand(2500).reshape((500,5))
df=pd.DataFrame(a,columns=["a","b","c","d","e"])
df.shape
# Out:
# (500, 5)

# %%
df.head()
# Out:
#           a         b         c         d         e
# 0  0.645500  0.203701  0.389390  0.215833  0.006560
# 1  0.991757  0.067533  0.041667  0.270347  0.961706
# 2  0.057141  0.545269  0.499087  0.524700  0.044735
# 3  0.268453  0.098289  0.700606  0.431488  0.676255
# 4  0.801289  0.879218  0.558813  0.009633  0.646973

# %%
df.tail()
# Out:
#             a         b         c         d         e
# 495  0.413295  0.251829  0.563073  0.842228  0.383106
# 496  0.966132  0.775432  0.876519  0.950180  0.149706
# 497  0.187918  0.110484  0.207905  0.941008  0.123363
# 498  0.266581  0.092906  0.667782  0.058861  0.040711
# 499  0.256793  0.778896  0.846831  0.863722  0.206215

# %%
df.tail(1)
# Out:
#             a         b         c         d         e
# 499  0.256793  0.778896  0.846831  0.863722  0.206215

# %%
df.head(1)
# Out:
#         a         b        c         d        e
# 0  0.6455  0.203701  0.38939  0.215833  0.00656

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
# a    500 non-null float64
# b    500 non-null float64
# c    500 non-null float64
# d    500 non-null float64
# e    500 non-null float64
# dtypes: float64(5)
# memory usage: 19.6 KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of             a         b         c         d         e
# 0    0.645500  0.203701  0.389390  0.215833  0.006560
# 1    0.991757  0.067533  0.041667  0.270347  0.961706
# 2    0.057141  0.545269  0.499087  0.524700  0.044735
# 3    0.268453  0.098289  0.700606  0.431488  0.676255
# 4    0.801289  0.879218  0.558813  0.009633  0.646973
# 5    0.179673  0.089761  0.491385  0.806936  0.481101
# 6    0.841899  0.053478  0.566589  0.332557  0.998377
# 7    0.304673  0.935188  0.899988  0.433394  0.537119
# 8    0.780334  0.505970  0.765849  0.030718  0.570213
# 9    0.006673  0.829528  0.025238  0.036643  0.533877
# 10   0.227606  0.956255  0.414707  0.008684  0.238384
# 11   0.537439  0.117442  0.814382  0.378645  0.441740
# 12   0.443198  0.443916  0.967205  0.055976  0.207676
# 13   0.399659  0.272639  0.689803  0.213035  0.407735
# 14   0.630430  0.180882  0.946753  0.403498  0.216109
# 15   0.063734  0.164100  0.672530  0.113460  0.286190
# ...

# %%
df.plot.scatter(x='a',y='b',c='blue',s=15,figsize=(12,3))

# %%
df['a'].plot.hist(bins=100,color="b")

# %%
plt.style.use('ggplot')

# %%
df['a'].plot.hist(alpha=1,bins=25,color='b')

# %%
plt.style.use('bmh')
df['a'].hist()

# %%
plt.style.use('bmh')+695847\
df[['a','b']].plot.box()

# %%
df['a'].hist()

# %%
df.plot.box()

# %%
df['a'].plot.kde()

# %%
df['a'].plot.density(lw=5,ls='--')

# %%
df.ix[0:30].plot.area(alpha=0.4)
# Out:
# c:\users\vkp\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
x=np.linspace(0,5,11)
y=x**2
plt.plot(x,y, 'b')
plt.xlabel('AC')
plt.ylabel('BC')
plt.title('CC')
plt.show()
